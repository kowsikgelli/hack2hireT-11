# %%
import pandas as pd

# %%
df=pd.read_excel("highRisk.xlsm")
highriskcountries=df["ENTITY_KEY"].values.tolist()
highriskcountries
# Out:
# ['AF', 'JI', 'PK', 'IS', 'TR', 'SR']

# %%
df=pd.read_excel("customer_ACCOUNT.xlsm")
accountKeys=df["account_key"].values.tolist()
primary_party_key=df["primary_party_key"].values.tolist()
acct_open_date=df["acct_open_date"].values.tolist()
accountInfo={}
for no,i in enumerate(accountKeys):
    accountInfo[i]={"primary_party_key":primary_party_key[no],"acct_open_date":acct_open_date[no]}
accountInfo
# Out:
# {'CASP_D04050165300009': {'primary_party_key': 'C1245363788_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780001': {'primary_party_key': 'C014581971C_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780002': {'primary_party_key': 'C014831981K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780003': {'primary_party_key': 'C015471980N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780004': {'primary_party_key': 'C016051974E_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780005': {'primary_party_key': 'C016801986E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780006': {'primary_party_key': 'C017421985G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780007': {'primary_party_key': 'C019501994H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780008': {'primary_party_key': 'C019991997H_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780009': {'primary_party_key': 'C022571975M_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780010': {'primary_party_key': 'C023191978H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780011': {'primary_party_key': 'C024781981H_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780012': {'primary_party_key': 'C025051990D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780013': {'primary_party_key': 'C025451993E_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780014': {'primary_party_key': 'C026201978G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780015': {'primary_party_key': 'C027501981Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780016': {'primary_party_key': 'C029371992H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780017': {'primary_party_key': 'C029771987M_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780018': {'primary_party_key': 'C031221990N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780019': {'primary_party_key': 'C031911982N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780020': {'primary_party_key': 'C033521978Z_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780021': {'primary_party_key': 'C035381992W_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780022': {'primary_party_key': 'C038251990H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780023': {'primary_party_key': 'C038701991C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780024': {'primary_party_key': 'C041001983H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780025': {'primary_party_key': 'C042521991G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780026': {'primary_party_key': 'C042711998G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780027': {'primary_party_key': 'C026611981H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780028': {'primary_party_key': 'C044571982H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780029': {'primary_party_key': 'C046211994G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780030': {'primary_party_key': 'C046951981D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780031': {'primary_party_key': 'C047171993K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780032': {'primary_party_key': 'C047971980R_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780033': {'primary_party_key': 'C052551993D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780034': {'primary_party_key': 'C058571991E_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780035': {'primary_party_key': 'C061181998E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780036': {'primary_party_key': 'C073111994Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780037': {'primary_party_key': 'C074171997K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780038': {'primary_party_key': 'C074421996K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780039': {'primary_party_key': 'C082261996R_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780040': {'primary_party_key': 'C084511995E_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780041': {'primary_party_key': 'C125600016G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780042': {'primary_party_key': 'C125600017K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780043': {'primary_party_key': 'C125600021N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780044': {'primary_party_key': 'C125600053W_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780045': {'primary_party_key': 'R00742500K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780046': {'primary_party_key': 'R21061800X_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780047': {'primary_party_key': 'X0019017823_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780048': {'primary_party_key': 'X123992_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780049': {'primary_party_key': 'X420739_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780050': {'primary_party_key': 'A00102811119_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780051': {'primary_party_key': 'A0039016212_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780052': {'primary_party_key': 'A0039031947_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780053': {'primary_party_key': 'A0050168953_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780054': {'primary_party_key': 'A0069021896_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780055': {'primary_party_key': 'A0089001566_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780056': {'primary_party_key': 'A0089028618_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780057': {'primary_party_key': 'A0119042958_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780058': {'primary_party_key': 'A01486799_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780059': {'primary_party_key': 'A0149030373_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780060': {'primary_party_key': 'A0149030535_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780061': {'primary_party_key': 'A0179010950_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780062': {'primary_party_key': 'A0179039681_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780063': {'primary_party_key': 'A0189025676_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780064': {'primary_party_key': 'A02075733_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780065': {'primary_party_key': 'A0209016366_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780066': {'primary_party_key': 'A0220220772_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780067': {'primary_party_key': 'A0279041668_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780068': {'primary_party_key': 'A0279048611_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780069': {'primary_party_key': 'A03007936_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780070': {'primary_party_key': 'A031308020_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780071': {'primary_party_key': 'A03149625_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780072': {'primary_party_key': 'A04062183_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780073': {'primary_party_key': 'A0479030140_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780074': {'primary_party_key': 'A0479033602_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780075': {'primary_party_key': 'A0489030534_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780076': {'primary_party_key': 'A0489036001_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780077': {'primary_party_key': 'A0549030996_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780078': {'primary_party_key': 'A0549031240_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780079': {'primary_party_key': 'A0549036820_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780080': {'primary_party_key': 'A0659002218_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780081': {'primary_party_key': 'A0709007015_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780082': {'primary_party_key': 'A082951997_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780083': {'primary_party_key': 'A10056268_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780084': {'primary_party_key': 'A1069029198_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780085': {'primary_party_key': 'A1079011365_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780086': {'primary_party_key': 'A1079020275_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780087': {'primary_party_key': 'A1079032451_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780088': {'primary_party_key': 'A1079035710_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780089': {'primary_party_key': 'A14055061_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780090': {'primary_party_key': 'A14093320_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780091': {'primary_party_key': 'A15046643_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780092': {'primary_party_key': 'A28050615_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780093': {'primary_party_key': 'A2889002693_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780094': {'primary_party_key': 'A2889042539_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780095': {'primary_party_key': 'A2889042750_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780096': {'primary_party_key': 'A33001070_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780097': {'primary_party_key': 'A33021275_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780098': {'primary_party_key': 'A33024967_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780099': {'primary_party_key': 'A47036577_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780100': {'primary_party_key': 'A48020003_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780101': {'primary_party_key': 'A48028284_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780102': {'primary_party_key': 'A66011755_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780103': {'primary_party_key': 'A74847_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780104': {'primary_party_key': 'AS25CS0001L_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780105': {'primary_party_key': 'AS61SS0117F_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780106': {'primary_party_key': 'AS62SS0001F_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780107': {'primary_party_key': 'AS62SS0064B_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780108': {'primary_party_key': 'AS62SS0076K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780109': {'primary_party_key': 'AS74SS0006K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780110': {'primary_party_key': 'AS75SS0058K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780111': {'primary_party_key': 'AS77SS0005G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780112': {'primary_party_key': 'AS80SS0043C_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780113': {'primary_party_key': 'AS83SS0025L_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780114': {'primary_party_key': 'AS84SS0019F_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780115': {'primary_party_key': 'AS92SS0087J_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780116': {'primary_party_key': 'AS96MC2029E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780117': {'primary_party_key': 'AS97SS0015G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780118': {'primary_party_key': 'AS97SS0045L_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780119': {'primary_party_key': 'AS99SS0093K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780120': {'primary_party_key': 'ASALARXX100_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780121': {'primary_party_key': 'C000151999D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780122': {'primary_party_key': 'C000191958C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780123': {'primary_party_key': 'C000261995M_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780124': {'primary_party_key': 'C000281995N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780125': {'primary_party_key': 'C000441986N_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780126': {'primary_party_key': 'C000591964D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780127': {'primary_party_key': 'C000911963D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780128': {'primary_party_key': 'C001381976N_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780129': {'primary_party_key': 'C001421988N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780130': {'primary_party_key': 'C001561968Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780131': {'primary_party_key': 'C001591980N_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780132': {'primary_party_key': 'C001911977W_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780133': {'primary_party_key': 'C002221977N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780134': {'primary_party_key': 'C004101986K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780135': {'primary_party_key': 'C004461971K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780136': {'primary_party_key': 'C004981982E_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780137': {'primary_party_key': 'C005241983K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780138': {'primary_party_key': 'C006391971Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780139': {'primary_party_key': 'C006421977W_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780140': {'primary_party_key': 'C006651979D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780141': {'primary_party_key': 'C007881983Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780142': {'primary_party_key': 'C007991977M_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780143': {'primary_party_key': 'C008071980K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780144': {'primary_party_key': 'C008831970D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780145': {'primary_party_key': 'C009671975N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780146': {'primary_party_key': 'C010261996M_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780147': {'primary_party_key': 'C010431985R_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780148': {'primary_party_key': 'C012481979H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780149': {'primary_party_key': 'C012871972D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780150': {'primary_party_key': 'C012952002Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780151': {'primary_party_key': 'C013181991G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780152': {'primary_party_key': 'C013211993K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780153': {'primary_party_key': 'C014491977C_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780154': {'primary_party_key': 'M160520016_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780155': {'primary_party_key': 'M160520017_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780156': {'primary_party_key': 'M160520018_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780157': {'primary_party_key': 'M160520019_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780158': {'primary_party_key': 'AT15MC0046J_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780159': {'primary_party_key': 'AT13SS0022F_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780160': {'primary_party_key': 'AT13SS0097K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780161': {'primary_party_key': 'AT13SS0163B_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780162': {'primary_party_key': 'AT13SS0172L_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780163': {'primary_party_key': 'AT14CC0003B_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780164': {'primary_party_key': 'AT14SS0148K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780165': {'primary_party_key': 'S9038913G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780166': {'primary_party_key': 'S9138913G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780167': {'primary_party_key': 'S9238913G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780168': {'primary_party_key': 'S9338913G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780169': {'primary_party_key': 'S9438913G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780170': {'primary_party_key': 'S9538913G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780171': {'primary_party_key': 'S9638913G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780172': {'primary_party_key': 'S9738913G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780173': {'primary_party_key': 'S9838913G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780174': {'primary_party_key': 'S9938913G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780175': {'primary_party_key': 'S9038923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780176': {'primary_party_key': 'S9138923G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780177': {'primary_party_key': 'S9238923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780178': {'primary_party_key': 'S9338923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780179': {'primary_party_key': 'S9438923G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780180': {'primary_party_key': 'S9538923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780181': {'primary_party_key': 'S9638923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780182': {'primary_party_key': 'S9738923G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780183': {'primary_party_key': 'S9838923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780184': {'primary_party_key': 'S9938923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780185': {'primary_party_key': 'S9038933G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780186': {'primary_party_key': 'S9138933G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780187': {'primary_party_key': 'S9238933G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780188': {'primary_party_key': 'S9338933G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780189': {'primary_party_key': 'S9438933G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780190': {'primary_party_key': 'S7138923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780191': {'primary_party_key': 'S7238923G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780192': {'primary_party_key': 'S7338923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780193': {'primary_party_key': 'S7438923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780194': {'primary_party_key': 'S7538923G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780195': {'primary_party_key': 'S7638923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780196': {'primary_party_key': 'S7738923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780197': {'primary_party_key': 'S7838923G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780198': {'primary_party_key': 'S7938923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780199': {'primary_party_key': 'S7038933G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780200': {'primary_party_key': 'X123992_00 ',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780201': {'primary_party_key': 'X420739_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780202': {'primary_party_key': 'M040919830309_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780203': {'primary_party_key': 'M050919830309_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780204': {'primary_party_key': 'M010844004_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780205': {'primary_party_key': 'AT08SS0246D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780206': {'primary_party_key': 'AT09MC0060E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780207': {'primary_party_key': 'AT10SS0048K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780208': {'primary_party_key': 'AT11CC0007D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780209': {'primary_party_key': 'AT11SS0212F_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780210': {'primary_party_key': 'C831911982N_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780211': {'primary_party_key': 'C833521978Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780212': {'primary_party_key': 'C835381992W_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780213': {'primary_party_key': 'C838251990H_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780214': {'primary_party_key': 'C838701991C_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780215': {'primary_party_key': 'C841001983H_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780216': {'primary_party_key': 'C842521991G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780217': {'primary_party_key': 'C842711998G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780218': {'primary_party_key': 'C844571982H_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780219': {'primary_party_key': 'C846211994G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780220': {'primary_party_key': 'C846951981D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780221': {'primary_party_key': 'C847171993K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780222': {'primary_party_key': 'C847971980R_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780223': {'primary_party_key': 'C852551993D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780224': {'primary_party_key': 'C858571991E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780225': {'primary_party_key': 'C861181998E_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780226': {'primary_party_key': 'C873111994Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780227': {'primary_party_key': 'C874171997K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780228': {'primary_party_key': 'C874421996K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780229': {'primary_party_key': 'C882261996R_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780230': {'primary_party_key': 'C884511995E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780231': {'primary_party_key': 'S8138923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780232': {'primary_party_key': 'S8238923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780233': {'primary_party_key': 'S8338923G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780234': {'primary_party_key': 'S8438923G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780235': {'primary_party_key': 'C546951981D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780236': {'primary_party_key': 'C547171993K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780237': {'primary_party_key': 'C547971980R_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780238': {'primary_party_key': 'C552551993D_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780239': {'primary_party_key': 'C558571991E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780240': {'primary_party_key': 'C561181998E_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780241': {'primary_party_key': 'C573111994Z_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780242': {'primary_party_key': 'C574171997K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780243': {'primary_party_key': 'C574421996K_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780244': {'primary_party_key': 'C582261996R_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780245': {'primary_party_key': 'C584511995E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780246': {'primary_party_key': 'S1659194G_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780247': {'primary_party_key': 'C15046643_00',
#   'acct_open_date': 1425081600000000000},
#  'CASP_D00630169780248': {'primary_party_key': 'M860520015_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D00630169780249': {'primary_party_key': 'S0035195D_00',
#   'acct_open_date': 1430352000000000000},
#  'CASP_D00630169780250': {'primary_party_key': 'S0035322A_00',
#   'acct_open_date': 1433030400000000000},
#  'CASP_D00630169780251': {'primary_party_key': 'S0035345J_00',
#   'acct_open_date': 1435622400000000000},
#  'CASP_D00630169780252': {'primary_party_key': 'S0035397C_00',
#   'acct_open_date': 1438300800000000000},
#  'CASP_D00630169780253': {'primary_party_key': 'S0036415J_00',
#   'acct_open_date': 1440979200000000000},
#  'CASP_D00630169780254': {'primary_party_key': 'S0036469Z_00',
#   'acct_open_date': 1443571200000000000},
#  'CASP_D35230169780240': {'primary_party_key': 'C353222220C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780241': {'primary_party_key': 'C353222221C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780242': {'primary_party_key': 'C352222222C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780243': {'primary_party_key': 'C353222223C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780244': {'primary_party_key': 'C353222224C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780245': {'primary_party_key': 'C353222225C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780246': {'primary_party_key': 'C353222226C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780247': {'primary_party_key': 'C353222227C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780248': {'primary_party_key': 'C353222228C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35230169780249': {'primary_party_key': 'C353222229C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780241': {'primary_party_key': 'C3560001D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780242': {'primary_party_key': 'C3560002D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780243': {'primary_party_key': 'C3560003D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780244': {'primary_party_key': 'C3560004D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780245': {'primary_party_key': 'C3560005D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780246': {'primary_party_key': 'C3560006D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780247': {'primary_party_key': 'S1111111G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780248': {'primary_party_key': 'S1111112G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780249': {'primary_party_key': 'S1111113G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780250': {'primary_party_key': 'S1111114G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780251': {'primary_party_key': 'S1111115G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780252': {'primary_party_key': 'S1111116G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780253': {'primary_party_key': 'S1111117G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780254': {'primary_party_key': 'S1111118G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780255': {'primary_party_key': 'S1111119G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780256': {'primary_party_key': 'S1111120G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780257': {'primary_party_key': 'S1111121G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780258': {'primary_party_key': 'S1111122G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780259': {'primary_party_key': 'S1111123G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780260': {'primary_party_key': 'S1111124G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780261': {'primary_party_key': 'S1111125G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780262': {'primary_party_key': 'S1111126G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780263': {'primary_party_key': 'S1111127G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780264': {'primary_party_key': 'S1111128G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780265': {'primary_party_key': 'S1111129G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D35630169780266': {'primary_party_key': 'S1111130G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D36030169780241': {'primary_party_key': 'C36000001C_00',
#   'acct_open_date': 1600041600000000000},
#  'CASP_D36030169780242': {'primary_party_key': 'C36000002C_00',
#   'acct_open_date': 1600214400000000000},
#  'CASP_D36030169780243': {'primary_party_key': 'C36000003C_00',
#   'acct_open_date': 1379203200000000000},
#  'CASP_D37130169780241': {'primary_party_key': 'C3710001N_00',
#   'acct_open_date': 1379289600000000000},
#  'CASP_D37230169780241': {'primary_party_key': 'C3720000D_00',
#   'acct_open_date': 1379376000000000000},
#  'CASP_D37230169780242': {'primary_party_key': 'C3720001D_00',
#   'acct_open_date': 1379462400000000000},
#  'CASP_D37230169780243': {'primary_party_key': 'C3720002D_00',
#   'acct_open_date': 1379548800000000000},
#  'CASP_D37230169780244': {'primary_party_key': 'S3720000F_00',
#   'acct_open_date': 1379635200000000000},
#  'CASP_D37230169780245': {'primary_party_key': 'S3720001F_00',
#   'acct_open_date': 1379721600000000000},
#  'CASP_D37230169780246': {'primary_party_key': 'S3720002F_00',
#   'acct_open_date': 1379808000000000000},
#  'CASP_D37230169780247': {'primary_party_key': 'C3730000N_00',
#   'acct_open_date': 1379894400000000000},
#  'CASP_D37230169780248': {'primary_party_key': 'C355111110C_00',
#   'acct_open_date': 1379980800000000000},
#  'CASP_D37230169780249': {'primary_party_key': 'C355111111C_00',
#   'acct_open_date': 1380067200000000000},
#  'CASP_D33590169780249': {'primary_party_key': 'C359600016G_00',
#   'acct_open_date': 1380153600000000000},
#  'CASP_D33590169780250': {'primary_party_key': 'C359600016G_00',
#   'acct_open_date': 1380240000000000000},
#  nan: {'primary_party_key': nan, 'acct_open_date': None},
#  'CASP_D20100169780240': {'primary_party_key': 'C0588S30F3A_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780241': {'primary_party_key': 'C201227388N_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780242': {'primary_party_key': 'C0654S20F4A_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780243': {'primary_party_key': 'C340062019C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780244': {'primary_party_key': 'C396302019D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780245': {'primary_party_key': 'C29964200C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780246': {'primary_party_key': 'C34119000D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780247': {'primary_party_key': 'T09CC0004J_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780248': {'primary_party_key': 'R53402322C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780249': {'primary_party_key': 'C008542003M_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780250': {'primary_party_key': 'C008542010G_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780251': {'primary_party_key': 'C008551982Z_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780252': {'primary_party_key': 'C008551993H_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780253': {'primary_party_key': 'C179762011E_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780254': {'primary_party_key': 'C179762016D_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780255': {'primary_party_key': 'C179772008R_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780256': {'primary_party_key': 'C179772009Z_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780257': {'primary_party_key': 'D468914C_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780258': {'primary_party_key': 'D47043000_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780259': {'primary_party_key': 'DS141822_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780260': {'primary_party_key': 'R53402399A_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780261': {'primary_party_key': 'C428622019R_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780262': {'primary_party_key': 'C315012019K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780263': {'primary_party_key': 'C315032019M_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780264': {'primary_party_key': 'DS109962_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780265': {'primary_party_key': 'GTANZTZTX_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780266': {'primary_party_key': 'GUNITARXVIII_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780267': {'primary_party_key': 'PT175711_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780268': {'primary_party_key': 'C004412020H_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780269': {'primary_party_key': 'PKJ0734171_01',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780270': {'primary_party_key': 'C02790FH_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780271': {'primary_party_key': 'P18FV08030_01',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780272': {'primary_party_key': 'DS212766_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780273': {'primary_party_key': 'R53402364M_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780274': {'primary_party_key': 'R53402365K_00',
#   'acct_open_date': 1427760000000000000},
#  'CASP_D20100169780275': {'primary_party_key': 'DS249944_00',
#   'acct_open_date': 1427846400000000000},
#  'CASP_D20100169780276': {'primary_party_key': 'PBM74KH953_01',
#   'acct_open_date': 1427932800000000000},
#  'CASP_D34300169780211': {'primary_party_key': 'C343000011H_00',
#   'acct_open_date': 1569888000000000000},
#  'CASP_D34300169780212': {'primary_party_key': 'C343000012H_00',
#   'acct_open_date': 1569974400000000000},
#  'CASP_D34300169780213': {'primary_party_key': 'C343000021H_00',
#   'acct_open_date': 1570060800000000000},
#  'CASP_D34300169780214': {'primary_party_key': 'C343000022H_00',
#   'acct_open_date': 1570147200000000000},
#  'CASP_D34300169780215': {'primary_party_key': 'C343000031H_00',
#   'acct_open_date': 1570233600000000000},
#  'CASP_D34300169780216': {'primary_party_key': 'C343000031H_00',
#   'acct_open_date': 1544054400000000000},
#  'CASP_D34300169780217': {'primary_party_key': 'C343000032H_00',
#   'acct_open_date': 1570233600000000000},
#  'CASP_D34300169780218': {'primary_party_key': 'C343000032H_00',
#   'acct_open_date': 1544054400000000000},
#  'CASP_D34300169780219': {'primary_party_key': 'C343000033H_00',
#   'acct_open_date': 1570233600000000000},
#  'CASP_D34300169780220': {'primary_party_key': 'C343000033H_00',
#   'acct_open_date': 1544054400000000000},
#  'CASP_D34300169780221': {'primary_party_key': 'C343000034H_00',
#   'acct_open_date': 1570233600000000000},
#  'CASP_D34300169780222': {'primary_party_key': 'C343000034H_00',
#   'acct_open_date': 1544054400000000000},
#  'CASP_D34300169780223': {'primary_party_key': 'C343000041H_00',
#   'acct_open_date': 1570233600000000000},
#  'CASP_D34300169780224': {'primary_party_key': 'C343000041H_00',
#   'acct_open_date': 1544054400000000000},
#  'CASP_D34300169780225': {'primary_party_key': 'C343000042H_00',
#   'acct_open_date': 1570233600000000000},
#  'CASP_D34300169780226': {'primary_party_key': 'C343000042H_00',
#   'acct_open_date': 1544054400000000000},
#  'CASP_D34300169780227': {'primary_party_key': 'C343000051H_00',
#   'acct_open_date': 1569888000000000000},
#  'CASP_D34300169780228': {'primary_party_key': 'C343000061H_00',
#   'acct_open_date': 1569974400000000000},
#  'CASP_D34300169780229': {'primary_party_key': 'C343000071H_00',
#   'acct_open_date': 1570060800000000000},
#  'CASP_D34300169780230': {'primary_party_key': 'C343000081H_00',
#   'acct_open_date': 1570147200000000000},
#  'CASP_D34300169780231': {'primary_party_key': 'C343000091H_00',
#   'acct_open_date': 1569888000000000000},
#  'CASP_D34300169780232': {'primary_party_key': 'C343000101H_00',
#   'acct_open_date': 1569974400000000000},
#  'CASP_D34300169780233': {'primary_party_key': 'C343000111H_00',
#   'acct_open_date': 1570147200000000000},
#  'CASP_D34300169780234': {'primary_party_key': 'C343000111H_00',
#   'acct_open_date': 1543881600000000000},
#  'CASP_D34300169780235': {'primary_party_key': 'S87698751A_00',
#   'acct_open_date': 1543968000000000000},
#  'CASP_D34300169780236': {'primary_party_key': 'S87698752S_00',
#   'acct_open_date': 1544054400000000000},
#  'CASP_D34300169780237': {'primary_party_key': 'M87698753D_00',
#   'acct_open_date': 1538352000000000000},
#  'CASP_D34300169780238': {'primary_party_key': 'M87698754F_00',
#   'acct_open_date': 1538438400000000000},
#  'CASP_D34300169780239': {'primary_party_key': 'S87698755G_00',
#   'acct_open_date': 1538524800000000000},
#  'CASP_D34300169780240': {'primary_party_key': 'S87698756H_00',
#   'acct_open_date': 1538611200000000000},
#  'CASP_D34300169780241': {'primary_party_key': 'M87698757J_00',
#   'acct_open_date': 1538697600000000000},
#  'CASP_D34300169780242': {'primary_party_key': 'M87698758K_00',
#   'acct_open_date': 1538784000000000000},
#  'CASP_D34300169780243': {'primary_party_key': 'S87698759L_00',
#   'acct_open_date': 1538870400000000000},
#  'CASP_D34300169780244': {'primary_party_key': 'S88698750Z_00',
#   'acct_open_date': 1538956800000000000},
#  'CASP_D34300169780245': {'primary_party_key': 'S88698751X_00',
#   'acct_open_date': 1539043200000000000},
#  'CASP_D34300169780246': {'primary_party_key': 'S88698752C_00',
#   'acct_open_date': 1539129600000000000},
#  'CASP_D34300169780247': {'primary_party_key': 'M88698753V_00',
#   'acct_open_date': 1539216000000000000},
#  'CASP_D34300169780248': {'primary_party_key': 'M88698754B_00',
#   'acct_open_date': 1539302400000000000},
#  'CASP_D34300169780249': {'primary_party_key': 'S88698755N_00',
#   'acct_open_date': 1539388800000000000},
#  'CASP_D34300169780250': {'primary_party_key': 'S88698756N_00',
#   'acct_open_date': 1539475200000000000},
#  'CASP_D34300169780251': {'primary_party_key': 'M88698757M_00',
#   'acct_open_date': 1539561600000000000},
#  'CASP_D34300169780252': {'primary_party_key': 'M88698758Q_00',
#   'acct_open_date': 1539648000000000000},
#  'CASP_D34300169780253': {'primary_party_key': 'S88698759W_00',
#   'acct_open_date': 1539734400000000000},
#  'CASP_D34300169780254': {'primary_party_key': 'S89698750E_00',
#   'acct_open_date': 1539820800000000000},
#  'CASP_D34300169780255': {'primary_party_key': 'S89698751R_00',
#   'acct_open_date': 1539907200000000000},
#  'CASP_D34300169780256': {'primary_party_key': 'S89698752T_00',
#   'acct_open_date': 1539993600000000000},
#  'CASP_D34300169780257': {'primary_party_key': 'M89698753Y_00',
#   'acct_open_date': 1540080000000000000},
#  'CASP_D34300169780258': {'primary_party_key': 'M89698754U_00',
#   'acct_open_date': 1540166400000000000},
#  'CASP_D34300169780259': {'primary_party_key': 'S89698755I_00',
#   'acct_open_date': 1540252800000000000},
#  'CASP_D34300169780260': {'primary_party_key': 'S89698756O_00',
#   'acct_open_date': 1540339200000000000},
#  'CASP_D34300169780261': {'primary_party_key': 'M89698757P_00',
#   'acct_open_date': 1540425600000000000},
#  'CASP_D34300169780262': {'primary_party_key': 'M89698758A_00',
#   'acct_open_date': 1540512000000000000},
#  'CASP_D34300169780263': {'primary_party_key': 'S89698759S_00',
#   'acct_open_date': 1540598400000000000},
#  'CASP_D34300169780264': {'primary_party_key': 'S87198752G_00',
#   'acct_open_date': 1540857600000000000},
#  'CASP_D34300169780265': {'primary_party_key': 'M87198753H_00',
#   'acct_open_date': 1540944000000000000},
#  'CASP_D34300169780266': {'primary_party_key': 'X35300011D_00',
#   'acct_open_date': 1541030400000000000},
#  'CASP_D34300169780267': {'primary_party_key': 'X35300012D_00',
#   'acct_open_date': 1541116800000000000},
#  'CASP_D34300169780268': {'primary_party_key': 'X35300013D_00',
#   'acct_open_date': 1541203200000000000},
#  'CASP_P34300169780269': {'primary_party_key': 'X35300014D_00',
#   'acct_open_date': 1541289600000000000},
#  'DQSP_D34300169780271': {'primary_party_key': 'X35300015D_00',
#   'acct_open_date': 1541376000000000000},
#  'DQSP_P34300169780272': {'primary_party_key': 'X35300016D_00',
#   'acct_open_date': 1541462400000000000},
#  'ANSP_34300169780270': {'primary_party_key': 'X35300017D_00',
#   'acct_open_date': 1541548800000000000},
#  'AQSP_34300169780273': {'primary_party_key': 'X35300018D_00',
#   'acct_open_date': 1541635200000000000},
#  'AQSP_D34300169780274': {'primary_party_key': 'X35300019D_00',
#   'acct_open_date': 1541721600000000000},
#  'CASP_D34300169780280': {'primary_party_key': 'X35300022D_00',
#   'acct_open_date': 1541808000000000000},
#  'CASP_D34300169780291': {'primary_party_key': 'X35300033D_00',
#   'acct_open_date': 1541894400000000000},
#  'CASP_D37700169780111': {'primary_party_key': 'C37700111N_00',
#   'acct_open_date': 1541808000000000000},
#  'CASP_D37700169780222': {'primary_party_key': 'C37700222N_00',
#   'acct_open_date': 1541894400000000000},
#  'CASP_D34300122220211': {'primary_party_key': 'C343000222H_00',
#   'acct_open_date': 1570838400000000000},
#  'CASP_D19900122220211': {'primary_party_key': 'X199900011D_00',
#   'acct_open_date': 1599782400000000000},
#  'CASP_D19900122220212': {'primary_party_key': 'S199900011F_00',
#   'acct_open_date': 1628726400000000000},
#  'CASP_D28700122220000': {'primary_party_key': 'X287100011D_00',
#   'acct_open_date': 1541808000000000000},
#  'CASP_D40300122220000': {'primary_party_key': 'AS40300019F_00',
#   'acct_open_date': 1541894400000000000},
#  'CASP_D40500169711110': {'primary_party_key': 'C405000010H_00',
#   'acct_open_date': 1541980800000000000},
#  'CASP_D40500169711111': {'primary_party_key': 'C405000011H_00',
#   'acct_open_date': 1542067200000000000},
#  'CASP_D40500169780222': {'primary_party_key': 'C405000022H_00',
#   'acct_open_date': 1542153600000000000},
#  'CASP_D40500169733330': {'primary_party_key': 'C405000330H_00',
#   'acct_open_date': 1542240000000000000},
#  'CASP_D40500169733331': {'primary_party_key': 'C405000331H_00',
#   'acct_open_date': 1542326400000000000},
#  'CASP_D40500169744440': {'primary_party_key': 'C405000440H_00',
#   'acct_open_date': 1542412800000000000},
#  'CASP_D40500169755550': {'primary_party_key': 'C405000550H_00',
#   'acct_open_date': 1542499200000000000},
#  'CASP_D40500169755551': {'primary_party_key': 'C405000551H_00',
#   'acct_open_date': 1542585600000000000},
#  'CASP_D40500169766661': {'primary_party_key': 'C405000660H_00',
#   'acct_open_date': 1542672000000000000},
#  'CASP_D40500169777770': {'primary_party_key': 'C405000770H_00',
#   'acct_open_date': 1542758400000000000},
#  'CASP_D40500169777771': {'primary_party_key': 'C405000771H_00',
#   'acct_open_date': 1542844800000000000},
#  'CASP_D40500169888888': {'primary_party_key': 'C405000880H_00',
#   'acct_open_date': 1542931200000000000},
#  'CASP_D40500169799999': {'primary_party_key': 'C405000999H_00',
#   'acct_open_date': 1543017600000000000},
#  'CASP_D41300000001111': {'primary_party_key': 'C04130111G_00',
#   'acct_open_date': 1541894400000000000},
#  'CASP_D41300000002222': {'primary_party_key': 'C04130222G_00',
#   'acct_open_date': 1541980800000000000},
#  'CASP_D41300000003333': {'primary_party_key': 'C04130333G_00',
#   'acct_open_date': 1542067200000000000},
#  'CASP_D41300000004444': {'primary_party_key': 'C04130444G_00',
#   'acct_open_date': 1542153600000000000},
#  'CASP_D41300000005555': {'primary_party_key': 'C04130555G_00',
#   'acct_open_date': 1542240000000000000},
#  'CASP_D41300000006666': {'primary_party_key': 'C04130666G_00',
#   'acct_open_date': 1542326400000000000},
#  'CASP_D41300000007777': {'primary_party_key': 'C04130777G_00',
#   'acct_open_date': 1542412800000000000},
#  'CASP_D41300000008888': {'primary_party_key': 'C04130888G_00',
#   'acct_open_date': 1542499200000000000},
#  'CASP_D41300000009999': {'primary_party_key': 'C04130999G_00',
#   'acct_open_date': 1542585600000000000},
#  'CASP_D41300000001123': {'primary_party_key': 'C04130123G_00',
#   'acct_open_date': 1542672000000000000},
#  'CASP_D41300000002456': {'primary_party_key': 'C04130456G_00',
#   'acct_open_date': 1542758400000000000},
#  'CASP_D41300000003789': {'primary_party_key': 'C04130789G_00',
#   'acct_open_date': 1542844800000000000},
#  'CASP_D40000000001111': {'primary_party_key': 'C040011119_00',
#   'acct_open_date': 1542931200000000000},
#  'CASP_D40000000002222': {'primary_party_key': 'M0400123R_00',
#   'acct_open_date': 1543017600000000000},
#  'CASP_D43700000001111': {'primary_party_key': 'C043711119_00',
#   'acct_open_date': 1543104000000000000},
#  'CASP_D43700000002222': {'primary_party_key': 'M0437123R_00',
#   'acct_open_date': 1543190400000000000},
#  'CASP_D43700000003333': {'primary_party_key': 'M0437456R_00',
#   'acct_open_date': 1543276800000000000},
#  'CASP_D00630157111111': {'primary_party_key': 'C01570111G_00',
#   'acct_open_date': 1543363200000000000},
#  'CASP_D00630157222222': {'primary_party_key': 'C01570222G_00',
#   'acct_open_date': 1543449600000000000},
#  'CASP_D00630412222000': {'primary_party_key': 'C04120000G_00',
#   'acct_open_date': 1543536000000000000},
#  'CASP_D00630412222111': {'primary_party_key': 'C04120111G_00',
#   'acct_open_date': 1543622400000000000},
#  'CASP_D00630412222222': {'primary_party_key': 'C04120222G_00',
#   'acct_open_date': 1543708800000000000},
#  'CASP_D00630412222333': {'primary_party_key': 'C04120333G_00',
#   'acct_open_date': 1543795200000000000},
#  'CASP_D00630412222444': {'primary_party_key': 'C04120444G_00',
#   'acct_open_date': 1543881600000000000},
#  'CASP_D00630412222555': {'primary_party_key': 'C04120555G_00',
#   'acct_open_date': 1543968000000000000},
#  'CASP_D00630412222666': {'primary_party_key': 'C04120666G_00',
#   'acct_open_date': 1544054400000000000},
#  'CASP_D00630412222777': {'primary_party_key': 'C04120777G_00',
#   'acct_open_date': 1544140800000000000},
#  'CASP_D00406002222111': {'primary_party_key': 'C014061110C_00',
#   'acct_open_date': 1544227200000000000},
#  'CASP_D00406002222222': {'primary_party_key': 'C014061111C_00',
#   'acct_open_date': 1544313600000000000},
#  'CASP_D00406002222333': {'primary_party_key': 'C014063330C_00',
#   'acct_open_date': 1544400000000000000},
#  'CASP_D00406002222444': {'primary_party_key': 'C014063331C_00',
#   'acct_open_date': 1544486400000000000},
#  'CASP_D00406002222555': {'primary_party_key': 'C014063332C_00',
#   'acct_open_date': 1544572800000000000},
#  'CASP_D00406002222666': {'primary_party_key': 'C014062220C_00',
#   'acct_open_date': 1544659200000000000},
#  'CASP_D00406002222777': {'primary_party_key': 'C014062222C_00',
#   'acct_open_date': 1544745600000000000},
#  'CASP_D00406002222888': {'primary_party_key': 'C014063333C_00',
#   'acct_open_date': 1544832000000000000},
#  'CASP_D00406002222999': {'primary_party_key': 'C014064444C_00',
#   'acct_open_date': 1544918400000000000}}

# %%
df=pd.read_excel("customer_info.xlsm")

party_key=df["party_key"].values.tolist()
residential_country_cd=df["residential_country_cd"].values.tolist()
party_open_date=df["party_open_date"].values.tolist()
customerInfo={}
for no,i in enumerate(party_key):
    customerInfo[i]={"residential_country_cd":residential_country_cd[no],"party_open_date":party_open_date[no]}
customerInfo
# Out:
# {'S1659194G_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'AS25CS0001L_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857174400000000000},
#  'AS61SS0117F_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857174400000000000},
#  'AS62SS0001F_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857174400000000000},
#  'AS62SS0064B_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510019200000000000},
#  'AS62SS0076K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857174400000000000},
#  'AS74SS0006K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857174400000000000},
#  'AS75SS0058K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857174400000000000},
#  'AS77SS0005G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510019200000000000},
#  'AS80SS0043C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 852076800000000000},
#  'AS83SS0025L_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510019200000000000},
#  'AS84SS0019F_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857174400000000000},
#  'AS92SS0087J_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510019200000000000},
#  'C000151999D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C000191958C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C000261995M_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C000281995N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C000441986N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C000591964D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C000911963D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C001381976N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C001421988N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C001561968Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C001591980N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C001911977W_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C002221977N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C004101986K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C004461971K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C004981982E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C005241983K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C006391971Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C006421977W_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C006651979D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C007881983Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C007991977M_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1488672000000000000},
#  'C008071980K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1488672000000000000},
#  'C008831970D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1488672000000000000},
#  'C009671975N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1523145600000000000},
#  'C010261996M_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1520467200000000000},
#  'C010431985R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1518048000000000000},
#  'C012481979H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C012871972D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C012952002Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C013181991G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C013211993K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1551484800000000000},
#  'C014491977C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014581971C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C014831981K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C015471980N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C016051974E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C016801986E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C017421985G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C019501994H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C019991997H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C022571975M_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C023191978H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C024781981H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C025051990D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C025451993E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C026201978G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C026611981H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C027501981Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C029371992H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C029771987M_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C031221990N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C031911982N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C033521978Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C035381992W_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C038251990H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C038701991C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C041001983H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C042521991G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C042711998G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C044571982H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C046211994G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C046951981D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C047171993K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C047971980R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C052551993D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C058571991E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C061181998E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C073111994Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C074171997K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C074421996K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C082261996R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C084511995E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C125600016G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C125600017K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C125600021N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C125600053W_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'R00742500K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'R21061800X_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'X0019017823_00': {'residential_country_cd': 'BM',
#   'party_open_date': 920332800000000000},
#  'X123992_00': {'residential_country_cd': 'HK',
#   'party_open_date': 857347200000000000},
#  'X420739_00': {'residential_country_cd': 'MY',
#   'party_open_date': 1551657600000000000},
#  'A00102811119_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'A0039016212_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'A0039031947_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'A0050168953_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'A0069021896_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'A0089001566_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'A0089028618_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'A0119042958_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'A01486799_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'A0149030373_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'A0149030535_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'A0179010950_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'A0179039681_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'A0189025676_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'A02075733_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'A0209016366_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'A0220220772_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'A0279041668_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'A0279048611_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'A03007936_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'A031308020_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'A03149625_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'A04062183_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'A0479030140_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'A0479033602_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'A0489030534_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'A0489036001_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'A0549030996_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'A0549031240_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'A0549036820_00': {'residential_country_cd': 'SG',
#   'party_open_date': 921024000000000000},
#  'A0659002218_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'A0709007015_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'A082951997_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'A10056268_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'A1069029198_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'A1079011365_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'A1079020275_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'A1079032451_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'A1079035710_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'A14055061_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'A14093320_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'A15046643_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'A28050615_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'A2889002693_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'A2889042539_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'A2889042750_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'A33001070_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'A33021275_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'A33024967_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'A47036577_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'A48020003_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'A48028284_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'A66011755_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'A74847_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1044576000000000000},
#  'AS93SS0109A_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510451200000000000},
#  'AS96MC2029E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510537600000000000},
#  'AS97SS0015G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510624000000000000},
#  'AS97SS0045L_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510710400000000000},
#  'AS99SS0093K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510796800000000000},
#  'ASALARXX100_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510883200000000000},
#  'AT15MC0046J_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510969600000000000},
#  'AT13SS0022F_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511056000000000000},
#  'AT13SS0097K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511142400000000000},
#  'AT13SS0163B_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511228800000000000},
#  'AT13SS0172L_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511315200000000000},
#  'AT14CC0003B_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511401600000000000},
#  'AT14SS0148K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511488000000000000},
#  'AT08SS0246D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511142400000000000},
#  'AT09MC0060E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511228800000000000},
#  'AT10SS0048K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511315200000000000},
#  'AT11CC0007D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511401600000000000},
#  'AT11SS0212F_00': {'residential_country_cd': 'SG',
#   'party_open_date': 511488000000000000},
#  'M0019325_00': {'residential_country_cd': 'MY',
#   'party_open_date': 337219200000000000},
#  'M002157103_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M00393723_00': {'residential_country_cd': 'MY',
#   'party_open_date': 253929600000000000},
#  'M0100_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M01011986_00': {'residential_country_cd': 'MY',
#   'party_open_date': 504921600000000000},
#  'M0105_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0106_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0107_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0108_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0109_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M01092011_00': {'residential_country_cd': 'MY',
#   'party_open_date': 694224000000000000},
#  'M0110_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0111_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0116_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0117_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0118_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0119_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0120_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0121_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0122_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M03062010_00': {'residential_country_cd': 'MY',
#   'party_open_date': 618105600000000000},
#  'M030919830309_00': {'residential_country_cd': nan,
#   'party_open_date': 915148800000000000},
#  'M03102011_00': {'residential_country_cd': 'MY',
#   'party_open_date': 570844800000000000},
#  'M031229788_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M03165842_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M031689895_00': {'residential_country_cd': 'MY',
#   'party_open_date': 339206400000000000},
#  'M037982045_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M03985761_00': {'residential_country_cd': 'MY',
#   'party_open_date': 518400000000000000},
#  'M04021988_00': {'residential_country_cd': 'MY',
#   'party_open_date': 570931200000000000},
#  'M0493629_00': {'residential_country_cd': 'MY',
#   'party_open_date': 915148800000000000},
#  'M06082008_00': {'residential_country_cd': 'MY',
#   'party_open_date': 321667200000000000},
#  'M06411781_00': {'residential_country_cd': 'MY',
#   'party_open_date': 473385600000000000},
#  'M06487950_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M06798003_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M0722057_00': {'residential_country_cd': 'MY',
#   'party_open_date': -710380800000000000},
#  'M0737567_00': {'residential_country_cd': 'MY',
#   'party_open_date': -774230400000000000},
#  'M08015779_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M08016615_00': {'residential_country_cd': 'MY',
#   'party_open_date': 345340800000000000},
#  'M0801999_00': {'residential_country_cd': 'MY',
#   'party_open_date': 485136000000000000},
#  'M0802667_00': {'residential_country_cd': 'MY',
#   'party_open_date': 345340800000000000},
#  'M09706452_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M09760684_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M0987654321_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M0989009098_00': {'residential_country_cd': 'MY',
#   'party_open_date': 621302400000000000},
#  'M1000009_00': {'residential_country_cd': 'MY',
#   'party_open_date': 339984000000000000},
#  'M100215454_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M10086FE_00': {'residential_country_cd': 'MY',
#   'party_open_date': 128995200000000000},
#  'M10544004_00': {'residential_country_cd': 'MY',
#   'party_open_date': -142128000000000000},
#  'M1063685_00': {'residential_country_cd': 'MY',
#   'party_open_date': 915148800000000000},
#  'M10987601_00': {'residential_country_cd': 'MY',
#   'party_open_date': -285811200000000000},
#  'M10987602_00': {'residential_country_cd': 'MY',
#   'party_open_date': -285811200000000000},
#  'M10987604_00': {'residential_country_cd': 'MY',
#   'party_open_date': -285811200000000000},
#  'M10987605_00': {'residential_country_cd': 'MY',
#   'party_open_date': -285811200000000000},
#  'M10987610_00': {'residential_country_cd': 'MY',
#   'party_open_date': -285811200000000000},
#  'M10987612_00': {'residential_country_cd': 'MY',
#   'party_open_date': -285811200000000000},
#  'M10987613_00': {'residential_country_cd': 'MY',
#   'party_open_date': -285811200000000000},
#  'M1104105_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104125_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104164_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104165_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104181_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104200_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104223_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104246_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104250_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104252_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104265_00': {'residential_country_cd': 'MY',
#   'party_open_date': 342748800000000000},
#  'M1104750_00': {'residential_country_cd': 'MY',
#   'party_open_date': 252460800000000000},
#  'M11102101_00': {'residential_country_cd': 'MY',
#   'party_open_date': 299635200000000000},
#  'M11102102_00': {'residential_country_cd': 'MY',
#   'party_open_date': 299635200000000000},
#  'M11102105_00': {'residential_country_cd': 'MY',
#   'party_open_date': 299635200000000000},
#  'M1112012_00': {'residential_country_cd': 'MY',
#   'party_open_date': 567993600000000000},
#  'M112233_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M11223345B_00': {'residential_country_cd': 'MY',
#   'party_open_date': 393033600000000000},
#  'M1122345A_00': {'residential_country_cd': 'MY',
#   'party_open_date': 393033600000000000},
#  'M11234570_00': {'residential_country_cd': 'MY',
#   'party_open_date': 662688000000000000},
#  'M1133445A_00': {'residential_country_cd': 'MY',
#   'party_open_date': 393033600000000000},
#  'M11688FN_00': {'residential_country_cd': 'MY',
#   'party_open_date': 318297600000000000},
#  'M11699FN_00': {'residential_country_cd': 'MY',
#   'party_open_date': 337219200000000000},
#  'M1201002_00': {'residential_country_cd': 'MY',
#   'party_open_date': 316396800000000000},
#  'M1201805_00': {'residential_country_cd': 'MY',
#   'party_open_date': 327110400000000000},
#  'M1201807_00': {'residential_country_cd': 'MY',
#   'party_open_date': 339984000000000000},
#  'M1201825_00': {'residential_country_cd': 'MY',
#   'party_open_date': 718675200000000000},
#  'M1201826_00': {'residential_country_cd': 'MY',
#   'party_open_date': 687052800000000000},
#  'M1201835_00': {'residential_country_cd': 'MY',
#   'party_open_date': 718675200000000000},
#  'M1201842_00': {'residential_country_cd': 'MY',
#   'party_open_date': 718675200000000000},
#  'M1201867_00': {'residential_country_cd': 'MY',
#   'party_open_date': 718675200000000000},
#  'M1202003_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M1202007_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M1202008_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M1202009_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M1202010_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'S1000018Z': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'S1000017Z': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M1204001_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M1204002_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M1204004_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M121212H_00': {'residential_country_cd': nan,
#   'party_open_date': 422928000000000000},
#  'M121397484_00': {'residential_country_cd': 'MY',
#   'party_open_date': 496972800000000000},
#  'M1223669847_00': {'residential_country_cd': 'MY',
#   'party_open_date': 295488000000000000},
#  'M1223929A_00': {'residential_country_cd': 'MY',
#   'party_open_date': 45014400000000000},
#  'M1224345235_00': {'residential_country_cd': 'MY',
#   'party_open_date': 597888000000000000},
#  'M12345_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M123456_00': {'residential_country_cd': 'MY',
#   'party_open_date': 573350400000000000},
#  'M1234567_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M12345676_00': {'residential_country_cd': 'MY',
#   'party_open_date': 536457600000000000},
#  'M12345678_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M123456789_00': {'residential_country_cd': 'MY',
#   'party_open_date': 154137600000000000},
#  'M1234567890_00': {'residential_country_cd': 'MY',
#   'party_open_date': 408499200000000000},
#  'M12354445H_00': {'residential_country_cd': nan,
#   'party_open_date': 422928000000000000},
#  'M123607985_00': {'residential_country_cd': 'MY',
#   'party_open_date': 150595200000000000},
#  'M1237899_00': {'residential_country_cd': 'MY',
#   'party_open_date': 626745600000000000},
#  'M12412FD_00': {'residential_country_cd': 'MY',
#   'party_open_date': 1657843200000000000},
#  'M12453671_00': {'residential_country_cd': 'MY',
#   'party_open_date': 150595200000000000},
#  'M124914658_00': {'residential_country_cd': 'MY',
#   'party_open_date': 275443200000000000},
#  'M12497860_00': {'residential_country_cd': 'MY',
#   'party_open_date': 220320000000000000},
#  'M12544004_00': {'residential_country_cd': 'MY',
#   'party_open_date': 315532800000000000},
#  'M1254542354_00': {'residential_country_cd': 'MY',
#   'party_open_date': 282268800000000000},
#  'M12546_00': {'residential_country_cd': 'MY',
#   'party_open_date': 295488000000000000},
#  'M12978FW_00': {'residential_country_cd': 'MY',
#   'party_open_date': 80006400000000000},
#  'M12979FH_00': {'residential_country_cd': 'MY',
#   'party_open_date': 80006400000000000},
#  'M12980FD_00': {'residential_country_cd': 'MY',
#   'party_open_date': -153878400000000000},
#  'M12981FN_00': {'residential_country_cd': nan,
#   'party_open_date': 915148800000000000},
#  'M13392FG_00': {'residential_country_cd': 'MY',
#   'party_open_date': 80006400000000000},
#  'M13393FW_00': {'residential_country_cd': 'MY',
#   'party_open_date': 80006400000000000},
#  'M13434FG_00': {'residential_country_cd': 'MY',
#   'party_open_date': -681004800000000000},
#  'M13435FW_00': {'residential_country_cd': 'MY',
#   'party_open_date': -681004800000000000},
#  'M13436FH_00': {'residential_country_cd': 'MY',
#   'party_open_date': -681004800000000000},
#  'M13437FZ_00': {'residential_country_cd': 'MY',
#   'party_open_date': -681004800000000000},
#  'M13438FK_00': {'residential_country_cd': 'MY',
#   'party_open_date': -681004800000000000},
#  'M13490FM_00': {'residential_country_cd': 'MY',
#   'party_open_date': 157766400000000000},
#  'M13491FD_00': {'residential_country_cd': 'MY',
#   'party_open_date': 157766400000000000},
#  'M13492FD_00': {'residential_country_cd': 'MY',
#   'party_open_date': 157766400000000000},
#  'M13493FD_00': {'residential_country_cd': 'MY',
#   'party_open_date': 157766400000000000},
#  'M13569FN_00': {'residential_country_cd': 'MY',
#   'party_open_date': 326937600000000000},
#  'M13570FH_00': {'residential_country_cd': 'MY',
#   'party_open_date': 326937600000000000},
#  'M13571FZ_00': {'residential_country_cd': 'MY',
#   'party_open_date': 326937600000000000},
#  'M13588AX_00': {'residential_country_cd': 'MY',
#   'party_open_date': 326937600000000000},
#  'M13625561_00': {'residential_country_cd': 'MY', 'party_open_date': 0},
#  'M1405566545_00': {'residential_country_cd': 'MY',
#   'party_open_date': 473385600000000000},
#  'M143369_00': {'residential_country_cd': 'MY',
#   'party_open_date': 295488000000000000},
#  'M14741134_00': {'residential_country_cd': 'MY',
#   'party_open_date': 329875200000000000},
#  'M15544004_00': {'residential_country_cd': 'MY',
#   'party_open_date': 473385600000000000},
#  'M15951134_00': {'residential_country_cd': 'MY',
#   'party_open_date': 174960000000000000},
#  'M15978652_00': {'residential_country_cd': 'MY',
#   'party_open_date': 157766400000000000},
#  'M160520011_00': {'residential_country_cd': 'MY',
#   'party_open_date': 392169600000000000},
#  'M160520012_00': {'residential_country_cd': 'MY',
#   'party_open_date': 392169600000000000},
#  'M160520014_00': {'residential_country_cd': 'MY',
#   'party_open_date': 392169600000000000},
#  'M160520015_00': {'residential_country_cd': 'MY',
#   'party_open_date': 392169600000000000},
#  'M160520016_00': {'residential_country_cd': 'MY',
#   'party_open_date': 392169600000000000},
#  'M160520017_00': {'residential_country_cd': 'MY',
#   'party_open_date': 392169600000000000},
#  'M160520018_00': {'residential_country_cd': 'MY',
#   'party_open_date': 392169600000000000},
#  'M160520019_00': {'residential_country_cd': 'MY',
#   'party_open_date': 392169600000000000},
#  'M160520111_00': {'residential_country_cd': 'MY',
#   'party_open_date': 327024000000000000},
#  'M160520112_00': {'residential_country_cd': 'MY',
#   'party_open_date': 361670400000000000},
#  'M160520113_00': {'residential_country_cd': 'MY',
#   'party_open_date': 269654400000000000},
#  'M160520114_00': {'residential_country_cd': 'MY',
#   'party_open_date': 431395200000000000},
#  'M160520115_00': {'residential_country_cd': 'MY',
#   'party_open_date': 389145600000000000},
#  'M160520116_00': {'residential_country_cd': 'MY',
#   'party_open_date': 484012800000000000},
#  'M160520117_00': {'residential_country_cd': 'MY',
#   'party_open_date': 423619200000000000},
#  'M160520118_00': {'residential_country_cd': 'MY',
#   'party_open_date': 297302400000000000},
#  'M160520119_00': {'residential_country_cd': 'MY',
#   'party_open_date': 229996800000000000},
#  'M16082011_00': {'residential_country_cd': 'MY',
#   'party_open_date': 518400000000000000},
#  'M1626801_00': {'residential_country_cd': 'MY',
#   'party_open_date': 915148800000000000},
#  'M16428_00': {'residential_country_cd': 'MY',
#   'party_open_date': -49939200000000000},
#  'M17544004_00': {'residential_country_cd': 'MY',
#   'party_open_date': 473385600000000000},
#  'M180520111_00': {'residential_country_cd': 'MY',
#   'party_open_date': -22550400000000000},
#  'M18465134_00': {'residential_country_cd': 'MY',
#   'party_open_date': -51926400000000000},
#  'M200002_00': {'residential_country_cd': 'MY',
#   'party_open_date': 367459200000000000},
#  'M200003_00': {'residential_country_cd': 'MY',
#   'party_open_date': 367459200000000000},
#  'M20110304_00': {'residential_country_cd': 'MY',
#   'party_open_date': 47433600000000000},
#  'M20110305_00': {'residential_country_cd': 'MY',
#   'party_open_date': 50198400000000000},
#  'M20110306_00': {'residential_country_cd': 'MY',
#   'party_open_date': 43891200000000000},
#  'M20110307_00': {'residential_country_cd': 'MY',
#   'party_open_date': 33177600000000000},
#  'M20110308_00': {'residential_country_cd': 'MY',
#   'party_open_date': 42076800000000000},
#  'S0031691A_00': {'residential_country_cd': 'SG',
#   'party_open_date': -318297600000000000},
#  'S0031951A_00': {'residential_country_cd': 'SG',
#   'party_open_date': 915148800000000000},
#  'S0031985F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -693360000000000000},
#  'S0031996A_00': {'residential_country_cd': 'SG',
#   'party_open_date': -666144000000000000},
#  'S0032093E_00': {'residential_country_cd': 'SG',
#   'party_open_date': -508809600000000000},
#  'S0032127C_00': {'residential_country_cd': 'SG',
#   'party_open_date': -482371200000000000},
#  'S0032213Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': -542851200000000000},
#  'S0032506F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -601084800000000000},
#  'S0033400F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -615600000000000000},
#  'S0033413H_00': {'residential_country_cd': 'SG',
#   'party_open_date': -603244800000000000},
#  'S0033467G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -507340800000000000},
#  'S0033470G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -509241600000000000},
#  'S0033527D_00': {'residential_country_cd': 'SG',
#   'party_open_date': -653184000000000000},
#  'S0033673D_00': {'residential_country_cd': 'SG',
#   'party_open_date': -530668800000000000},
#  'S0033901F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -1015545600000000000},
#  'S0034076F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -552182400000000000},
#  'S0034119C_00': {'residential_country_cd': 'SG',
#   'party_open_date': -606355200000000000},
#  'S0034358G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -529459200000000000},
#  'S0034411G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -530150400000000000},
#  'S0035195D_00': {'residential_country_cd': 'SG',
#   'party_open_date': -285292800000000000},
#  'S0035322A_00': {'residential_country_cd': 'SG',
#   'party_open_date': -155779200000000000},
#  'S0035345J_00': {'residential_country_cd': 'SG',
#   'party_open_date': -88214400000000000},
#  'S0035397C_00': {'residential_country_cd': 'SG',
#   'party_open_date': -165283200000000000},
#  'S0035457J_00': {'residential_country_cd': 'SG',
#   'party_open_date': -577411200000000000},
#  'S0035463E_00': {'residential_country_cd': 'SG',
#   'party_open_date': -408499200000000000},
#  'S0035550Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': -561340800000000000},
#  'S0035597F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -505267200000000000},
#  'S0035606I_00': {'residential_country_cd': 'SG',
#   'party_open_date': -607564800000000000},
#  'S0035749I_00': {'residential_country_cd': 'SG',
#   'party_open_date': -476409600000000000},
#  'S0035869Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': -76550400000000000},
#  'S0035918A_00': {'residential_country_cd': 'SG',
#   'party_open_date': 473385600000000000},
#  'S0036415J_00': {'residential_country_cd': 'SG',
#   'party_open_date': -266976000000000000},
#  'S0036469Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': -939513600000000000},
#  'S0037164E_00': {'residential_country_cd': 'SG',
#   'party_open_date': -347328000000000000},
#  'S0037181E_00': {'residential_country_cd': 'SG',
#   'party_open_date': -597283200000000000},
#  'S0037543H_00': {'residential_country_cd': 'SG',
#   'party_open_date': -283392000000000000},
#  'S0037708B_00': {'residential_country_cd': 'MM',
#   'party_open_date': 783648000000000000},
#  'S0037709J_00': {'residential_country_cd': 'SG',
#   'party_open_date': -278208000000000000},
#  'S0037970J_00': {'residential_country_cd': 'MY',
#   'party_open_date': -385344000000000000},
#  'S0038095D_00': {'residential_country_cd': 'SG',
#   'party_open_date': -942192000000000000},
#  'S0038195J_00': {'residential_country_cd': 'SG',
#   'party_open_date': -544924800000000000},
#  'S0038482H_00': {'residential_country_cd': 'SG',
#   'party_open_date': -497232000000000000},
#  'S0038488G_00': {'residential_country_cd': 'MM',
#   'party_open_date': -65664000000000000},
#  'S0038628F_00': {'residential_country_cd': 'ID',
#   'party_open_date': -326073600000000000},
#  'S0038677D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 510019200000000000},
#  'S0038766E_00': {'residential_country_cd': 'SG',
#   'party_open_date': -676425600000000000},
#  'S0038913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841708800000000000},
#  'S9038913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841622400000000000},
#  'S9138913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841536000000000000},
#  'S9238913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841449600000000000},
#  'S9338913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841363200000000000},
#  'S9438913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841276800000000000},
#  'S9538913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841190400000000000},
#  'S9638913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841104000000000000},
#  'S9738913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -841017600000000000},
#  'S9838913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840931200000000000},
#  'S9938913G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840844800000000000},
#  'S9038923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840758400000000000},
#  'S9138923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840672000000000000},
#  'S9238923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840585600000000000},
#  'S9338923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840499200000000000},
#  'S9438923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840412800000000000},
#  'S9538923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840326400000000000},
#  'S9638923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840240000000000000},
#  'S9738923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840153600000000000},
#  'S9838923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840067200000000000},
#  'S9938923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839980800000000000},
#  'S9038933G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839894400000000000},
#  'S9138933G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839808000000000000},
#  'S9238933G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839721600000000000},
#  'S9338933G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839635200000000000},
#  'S9438933G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839548800000000000},
#  'S7138923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839462400000000000},
#  'S7238923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839376000000000000},
#  'S7338923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839289600000000000},
#  'S7438923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839203200000000000},
#  'S7538923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839116800000000000},
#  'S7638923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -839030400000000000},
#  'S7738923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838944000000000000},
#  'S7838923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838857600000000000},
#  'S7938923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838771200000000000},
#  'S7038933G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M040919830309_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838598400000000000},
#  'M050919830309_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838598400000000000},
#  'M010944004_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010844004_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'C831911982N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C833521978Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C835381992W_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C838251990H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C838701991C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C841001983H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C842521991G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C842711998G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C844571982H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C846211994G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C846951981D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C847171993K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C847971980R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C852551993D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C858571991E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C861181998E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C873111994Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C874171997K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C874421996K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C882261996R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C884511995E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'S8138923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840672000000000000},
#  'S8238923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840585600000000000},
#  'S8338923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840499200000000000},
#  'S8438923G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -840412800000000000},
#  'M010944005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010844005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010644005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010744005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010544005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'C546951981D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C547171993K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C547971980R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C552551993D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825897600000000000},
#  'C558571991E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C561181998E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C573111994Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C574171997K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1047081600000000000},
#  'C574421996K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920937600000000000},
#  'C582261996R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 195264000000000000},
#  'C584511995E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'M010914005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010814005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010614005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010714005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010514005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010924005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010824005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010624005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010724005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M010524005_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'C15046643_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'M860520015_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920332800000000000},
#  'C353222220C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C353222221C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C353222223C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C353222224C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C353222225C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C353222226C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C353222227C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C353222228C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C353222229C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C352222222C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C3560001D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C3560002D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C3560003D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C3560004D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 920678400000000000},
#  'C3560005D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C3560006D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'S1111111G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111112G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111113G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111114G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111115G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111116G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111117G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111118G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111119G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111120G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111121G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111122G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111123G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111124G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111125G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111126G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111127G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111128G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111129G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S1111130G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'C36000001C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C36000002C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C36000003C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 825984000000000000},
#  'C3710001N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 826070400000000000},
#  'C3720000D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 826070400000000000},
#  'C3720001D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 826070400000000000},
#  'C3720002D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 826070400000000000},
#  'S3720000F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S3720001F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S3720002F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'C0588S30F3A_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C201227388N_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C0654S20F4A_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C340062019C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C396302019D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C29964200C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C34119000D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'T09CC0004J_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'R53402322C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C008542003M_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C008542010G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C008551982Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C008551993H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C179762011E_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C179762016D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C179772008R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C179772009Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'D468914C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'D47043000_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'DS141822_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'R53402399A_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C428622019R_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C315012019K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C315032019M_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'DS109962_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'GTANZTZTX_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'GUNITARXVIII_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'PT175711_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C004412020H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'PKJ0734171_01': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C02790FH_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'P18FV08030_01': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'DS212766_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'R53402364M_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'R53402365K_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'DS249944_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'PBM74KH953_01': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000011H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000012H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000021H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000022H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000031H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000032H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000033H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000034H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000041H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000042H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000051H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000061H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000071H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000081H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000091H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000101H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C343000111H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'M87698753D_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M87698754F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S87698755G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S87698756H_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M87698757J_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M87698758K_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S87698759L_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S88698750Z_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S88698751X_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S88698752C_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M88698753V_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M88698754B_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S88698755N_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S88698756N_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M88698757M_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M88698758Q_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S88698759W_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S89698750E_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S89698751R_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S89698752T_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M89698753Y_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M89698754U_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S89698755I_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S89698756O_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M89698757P_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M89698758A_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S89698759S_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S87198750D_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S87198751F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'S87198752G_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'M87198753H_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'C355111110C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C355111111C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300011D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300012D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300013D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300014D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300015D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300016D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300017D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300018D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300019D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300022D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'X35300033D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C359600016G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'C343000222H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 857347200000000000},
#  'X199900011D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'S199900011F_00': {'residential_country_cd': 'SG',
#   'party_open_date': -838684800000000000},
#  'X287100011D_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'AS40300019F_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000010H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000011H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000022H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000330H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000331H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000440H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000550H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000551H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000660H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000770H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000771H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000880H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C405000999H_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130111G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130222G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130333G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130444G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130555G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130666G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130777G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130888G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130999G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130123G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130456G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04130789G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C040011119_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'M0400123R_00': {'residential_country_cd': 'US',
#   'party_open_date': -838684800000000000},
#  'C043711119_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'M0437123R_00': {'residential_country_cd': 'US',
#   'party_open_date': -838684800000000000},
#  'M0437456R_00': {'residential_country_cd': 'US',
#   'party_open_date': -838684800000000000},
#  'C01570111G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C01570222G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04120000G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04120111G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04120222G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04120333G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04120444G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04120555G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04120666G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C04120777G_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  nan: {'residential_country_cd': nan, 'party_open_date': None},
#  'C014061110C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014061111C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014063330C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014063331C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014063332C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014062220C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014062222C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014063333C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000},
#  'C014064444C_00': {'residential_country_cd': 'SG',
#   'party_open_date': 1046995200000000000}}

# %%
df=pd.read_excel("tarsactions.xlsm")
account_key="CASP_D00630169780019"
df1=df.loc[df[' Account_Key']==account_key]
risk=False
transCount=len(df1)
customerCountry=customerInfo[accountInfo[account_key]["primary_party_key"]]["residential_country_cd"]
if customerCountry in highriskcountries:
    risk=True
    print("High risk at case H1")
else:
    print("No risk at case H1")
df1
# Out:
# No risk at case H1
#    Transfer_Key           Account_Key   Transaction_Amount(in $)  \
# 54          K55  CASP_D00630169780019                        100
# 55          K56  CASP_D00630169780019                        100
# 56          K57  CASP_D00630169780019                        100
# 57          K58  CASP_D00630169780019                        100
# 58          K59  CASP_D00630169780019                        100
# 59          K60  CASP_D00630169780019                        100
# 60          K61  CASP_D00630169780019                        100
# 61          K62  CASP_D00630169780019                        100
# 62          K63  CASP_D00630169780019                        100
# 63          K64  CASP_D00630169780019                        100
# 64          K65  CASP_D00630169780019                        100
# 65          K66  CASP_D00630169780019                        100
#
#     Transaction Type  Transaction_Origin/Destination  Transaction_Date
# 54               INN                              SR        2019-01-01
# 55               INN                              SR        2019-01-02
# 56               INN                              TR        2019-01-03
# 57               INN                              AF        2019-01-04
# 58               INN                              AF        2019-01-05
# 59               INN                              SR        2019-01-06
# 60               INN                              SR        2019-01-07
# 61               INN                              SR        2020-01-08
# 62               INN                              SR        2020-01-09
# 63               INN                              SR        2020-01-08
# 64               INN                              AF        2020-01-10
# 65               INN                              SR        2020-01-11

# %%
df2=df1.loc[df[' Transaction Type']=="INN"]
tran_amount_inn=sum(df2[" Transaction_Amount(in $)"])
if tran_amount_inn>1000:
    print("High risk at case H2")
else:
    print("no risk at case H2")
df2[" Transaction_Date"].values.tolist()
# Out:
# High risk at case H2
# [1546300800000000000,
#  1546387200000000000,
#  1546473600000000000,
#  1546560000000000000,
#  1546646400000000000,
#  1546732800000000000,
#  1546819200000000000,
#  1578441600000000000,
#  1578528000000000000,
#  1578441600000000000,
#  1578614400000000000,
#  1578700800000000000]

# %%
df2=df1.loc[df[' Transaction Type']=="OUT"]
tran_amount_out=sum(df2[" Transaction_Amount(in $)"])
if sum(df2[" Transaction_Amount(in $)"])>800:
    print("High risk at case H3")
else:
    print("no risk at case H3")
# Out:
# no risk at case H3

# %%
transfordays={}
data=df[" Transaction_Date"].values.tolist()
for i in data:
    if i in transfordays:
        transfordays[i]+=1
    else:
        transfordays[i]=1
max=0
for i in transfordays:
    if (transfordays[i]>max):
        max=transfordays[i]
max
# Out:
# 40

# %%
def risk(tran_count,tran_amount_inn,tran_amount_out,tran_perday,risk_country):
    if risk_country==True and tran_count>10:
        return "H1"
    elif tran_amount_inn>1000:
        return "H2"
    elif tran_amount_out>800:
        return "H3"
    elif tran_perday>20:
        return "H4"
    elif (risk_country==True or risk_country==False) and tran_count>6:
        return "M1"
    elif tran_amount_inn>600 and tran_amount_inn<=1000:
        return "M2"
    elif tran_amount_out > 500 and tran_amount_out <= 800:
        return "M3"
    elif tran_perday>10 and tran_perday<=20:
        return "M4"
    elif risk_country==False and tran_count<10:
        return "L1"
    elif tran_amount_inn<=600:
        return "L2"
    elif tran_amount_out<=500:
        return "L3"
    elif tran_perday<=10:
        return "L4"

risk(transCount,tran_amount_inn,tran_amount_out,max,risk)
# Out:
# 'H2'
